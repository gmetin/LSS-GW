# %%
import ligo.skymap as ls

# %%
from ligo.skymap.io.fits import read_sky_map
from astropy.io import fits
import matplotlib.pyplot as plt

# %%
smap = read_sky_map( "LALInference_skymap1.fits")
file =  "LALInference_skymap1.fits"

# %%
smap
# Out:
# (array([2.5783892e-43, 8.2750789e-14, 2.5275632e-33, ..., 0.0000000e+00,
#         0.0000000e+00, 1.4732790e-25], dtype=float32),
#  OrderedDict([('nest', True),
#               ('objid', 0),
#               ('gps_time', 1128678900.447012),
#               ('gps_creation_time', 1147635073.0),
#               ('creator', 'run_sky_area.py')]))

# %%
from astropy.coordinates import SkyCoord
from astropy.io import fits
from astropy import units as u
import ligo.skymap.plot
from matplotlib import pyplot as plt

url = 'https://dcc.ligo.org/public/0146/G1701985/001/bayestar_no_virgo.fits.gz'
center = SkyCoord.from_name('NGC 4993')

fig = plt.figure(figsize=(4, 4), dpi=100)
ax = plt.axes(
    [0.05, 0.05, 0.9, 0.9],
    projection='astro globe',
    center=center)

ax_inset = plt.axes(
    [0.59, 0.3, 0.4, 0.4],
    projection='astro zoom',
    center=center,
    radius=10*u.deg)

for key in ['ra', 'dec']:
    ax_inset.coords[key].set_ticklabel_visible(False)
    ax_inset.coords[key].set_ticks_visible(False)
ax.grid()
ax.mark_inset_axes(ax_inset)
ax.connect_inset_axes(ax_inset, 'upper left')
ax.connect_inset_axes(ax_inset, 'lower left')
ax_inset.scalebar((0.1, 0.1), 5 * u.deg).label()
ax_inset.compass(0.9, 0.1, 0.2)

ax.imshow_hpx(url, cmap='cylon')
ax_inset.imshow_hpx(url, cmap='cylon')
ax_inset.plot(
    center.ra.deg, center.dec.deg,
    transform=ax_inset.get_transform('world'),
    marker=ligo.skymap.plot.reticle(),
    markersize=30,
    markeredgewidth=3)

# %%
fig = plt.figure(figsize=(4, 4), dpi=100)

#ax = plt.axes(projection='astro hours mollweide')
#ax = plt.axes(projection='geo globe', center='-50d +23d')
ax = plt.axes(projection='geo aitoff')


ax.imshow_hpx(file, cmap='cylon')
